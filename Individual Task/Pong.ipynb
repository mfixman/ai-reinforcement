# %%
# !pip install gputil
# !pip install ray[rllib]
# !pip install gym[atari,accept-rom-license]

# %%
# !pip install -U ipywidgets

# %%
import ray
import ray.rllib.algorithms.dqn as dqn
from ray import tune
# Out:
# WARNING:tensorflow:From d:\Users\Sean\anaconda3\envs\INM705\lib\site-packages\ray\rllib\utils\framework.py:126: The name tf.logging.set_verbosity is deprecated. Please use tf.compat.v1.logging.set_verbosity instead.
# 2024-05-11 10:38:44,188	WARNING compression.py:16 -- lz4 not available, disabling sample compression. This will significantly impact RLlib performance. To install lz4, run `pip install lz4`.

# %%
config = dqn.DQNConfig()



config["env"] = "Pong-ram-v4"
config["framework"] = "torch"

#Environment configs
config['model']['grayscale'] = True
config['model']['dim'] = 84
config['model']['zero_mean'] = True
config['sample_batch_size'] = 4
# config['rollout_fragment_length'] = 4

# Rainbow DQN Parameters
config["dueling"] = tune.grid_search([True,False])
config["double_q"] = tune.grid_search([True,False])
config["noisy"] = False

# Rainbow DQN numerical Parameters
config['num_atoms'] = 1
config["n_step"] = 10
config['v_min'] = -12.0
config['v_max'] = 12.0
config['sigma0'] = 0.2

# DQN layers
config["model"] = {"fcnet_hiddens": [512], "fcnet_activation": "relu"}

# Action selection configs
config['exploration_config'] = {'type': 'EpsilonGreedy', 'initial_epsilon':1.0, 'final_epsilon':.001, 'epsilon_timesteps': 40000}

# Replay buffer configurations
# https://docs.ray.io/en/latest/_modules/ray/rllib/utils/replay_buffers/prioritized_replay_buffer.html 
config["replay_buffer_config"] = {
                "type": "MultiAgentPrioritizedReplayBuffer",
                "capacity": 75000,
                "prioritized_replay_alpha": 0.7,
                "prioritized_replay_beta": 0.3,
                "prioritized_replay_eps": 0.00001,
                # "replay_sequence_length" : 1
            }

# Training configs
config["train_batch_size"] = 32
config["timesteps_per_iteration"] = 10000   
config["target_network_update_freq"] = 7500
config['gamma'] = 0.99
config['lr'] = 0.001
# config['adam_epsilon'] = 0.0020
config["num_gpus"] = 1
config['num_workers'] = 8
# config['compress_observations'] = True  

analysis3 = tune.run("DQN", name = "Model", metric = "episode_reward_min", num_samples = 1, checkpoint_freq = 10, config = config)
# Out:
# 2024-05-11 14:52:17,483	INFO tune.py:614 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# 2024-05-11 14:52:17,487	WARNING callback.py:136 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-05-12 07:32:45</td></tr>
# <tr><td>Running for: </td><td>16:40:27.96        </td></tr>
# <tr><td>Memory:      </td><td>11.7/13.9 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                 </th><th>status    </th><th>loc            </th><th>double_q  </th><th>dueling  </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">     ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Pong-ram-v4_adf97_00000</td><td>TERMINATED</td><td>127.0.0.1:14728</td><td>True      </td><td>True     </td><td style="text-align: right;">  2000</td><td style="text-align: right;">         14116  </td><td style="text-align: right;">2000000</td><td style="text-align: right;">  -11.6 </td><td style="text-align: right;">                   8</td><td style="text-align: right;">                 -20</td><td style="text-align: right;">           3668.28</td></tr>
# <tr><td>DQN_Pong-ram-v4_adf97_00001</td><td>TERMINATED</td><td>127.0.0.1:13736</td><td>False     </td><td>True     </td><td style="text-align: right;">  2000</td><td style="text-align: right;">         16972.2</td><td style="text-align: right;">2000000</td><td style="text-align: right;">  -12.16</td><td style="text-align: right;">                  -1</td><td style="text-align: right;">                 -21</td><td style="text-align: right;">           3669.67</td></tr>
# <tr><td>DQN_Pong-ram-v4_adf97_00002</td><td>TERMINATED</td><td>127.0.0.1:16616</td><td>True      </td><td>False    </td><td style="text-align: right;">  2000</td><td style="text-align: right;">         14347.8</td><td style="text-align: right;">2000000</td><td style="text-align: right;">  -13.22</td><td style="text-align: right;">                  -2</td><td style="text-align: right;">                 -19</td><td style="text-align: right;">           3778.73</td></tr>
# <tr><td>DQN_Pong-ram-v4_adf97_00003</td><td>TERMINATED</td><td>127.0.0.1:13776</td><td>False     </td><td>False    </td><td style="text-align: right;">  2000</td><td style="text-align: right;">         14175.4</td><td style="text-align: right;">2000000</td><td style="text-align: right;">  -11.35</td><td style="text-align: right;">                   3</td><td style="text-align: right;">                 -19</td><td style="text-align: right;">           5334.26</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name                 </th><th style="text-align: right;">  agent_timesteps_total</th><th>connector_metrics                                                                                                                                               </th><th>counters                                                                                                                                                                                                 </th><th>custom_metrics  </th><th>env_runner_results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    </th><th style="text-align: right;">  episode_len_mean</th><th>episode_media  </th><th style="text-align: right;">  episode_return_max</th><th style="text-align: right;">  episode_return_mean</th><th style="text-align: right;">  episode_return_min</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_mean</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episodes_this_iter</th><th style="text-align: right;">  episodes_timesteps_total</th><th>info  </th><th style="text-align: right;">  num_agent_steps_sampled</th><th style="text-align: right;">  num_agent_steps_sampled_lifetime</th><th style="text-align: right;">  num_agent_steps_trained</th><th style="text-align: right;">  num_env_steps_sampled</th><th style="text-align: right;">  num_env_steps_sampled_lifetime</th><th style="text-align: right;">  num_env_steps_sampled_this_iter</th><th style="text-align: right;">  num_env_steps_sampled_throughput_per_sec</th><th style="text-align: right;">  num_env_steps_trained</th><th style="text-align: right;">  num_env_steps_trained_this_iter</th><th style="text-align: right;">  num_env_steps_trained_throughput_per_sec</th><th style="text-align: right;">  num_episodes</th><th style="text-align: right;">  nu ...
# </thead>
# <tbody>
# <tr><td>DQN_Pong-ram-v4_adf97_00000</td><td style="text-align: right;">                2000000</td><td>{&#x27;ObsPreprocessorConnector_ms&#x27;: 0.03664350509643555, &#x27;StateBufferConnector_ms&#x27;: 0.0020792484283447266, &#x27;ViewRequirementAgentConnector_ms&#x27;: 0.11044120788574219} </td><td>{&#x27;num_env_steps_sampled&#x27;: 2000000, &#x27;num_env_steps_trained&#x27;: 6396800, &#x27;num_agent_steps_sampled&#x27;: 2000000, &#x27;num_agent_steps_trained&#x27;: 6396800, &#x27;last_target_update_ts&#x27;: 1995000, &#x27;num_target_updates&#x27;: 266}</td><td>{}              </td><td>{&#x27;episode_reward_max&#x27;: 8.0, &#x27;episode_reward_min&#x27;: -20.0, &#x27;episode_reward_mean&#x27;: -11.6, &#x27;episode_len_mean&#x27;: 3668.28, &#x27;episode_media&#x27
# 2024-05-11 20:29:35,025	WARNING util.py:201 -- The `on_step_begin` operation took 0.517 s, which may be a performance bottleneck.
# 2024-05-12 07:32:45,387	WARNING experiment_state.py:205 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this error by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0).
# 2024-05-12 07:32:45,451	INFO tune.py:1007 -- Wrote the latest version of all result files and experiment state to 'C:/Users/Sean/ray_results/Model' in 0.2093s.
# 2024-05-12 07:32:47,135	INFO tune.py:1039 -- Total run time: 60029.65 seconds (60027.75 seconds for the tuning loop).

# %%
print(analysis2.results)
# Out:
# {'adf97_00000': {'custom_metrics': {}, 'episode_media': {}, 'info': {'learner': {'default_policy': {'custom_metrics': {}, 'learner_stats': {'mean_q': -0.33657023310661316, 'min_q': -1.061773657798767, 'max_q': 0.47187069058418274, 'cur_lr': 0.001}, 'model': {}, 'num_grad_updates_lifetime': 199900.0, 'diff_num_grad_updates_vs_sampler_policy': 2342.625, 'td_error': array([-0.23161872, -0.08270526, -0.0184001 , -0.10676962,  0.08852077,
#         0.0485037 ,  0.11004633,  0.02867132, -0.05785266, -0.12899739,
#        -0.37594083,  0.02211392,  0.19209304,  0.15735868,  0.04034206,
#        -0.61942863,  0.07656941, -0.03717953,  0.08788425,  0.09292406,
#        -0.01807331, -0.2785567 , -0.28668052,  0.0481891 ,  0.04343653,
#         0.08189975,  0.13936234,  0.5637545 ,  0.35407022, -0.00688224,
#         0.08117461,  0.6255276 ], dtype=float32), 'mean_td_error': 0.01979239657521248}}, 'num_env_steps_sampled': 2000000, 'num_env_steps_trained': 6396800, 'num_agent_steps_sampled': 2000000, 'num_agent_steps_trained': 6396800, 'last_target_update_ts': 1995000, 'num_target_updates': 266}, 'sampler_results': {'episode_reward_max': 8.0, 'episode_reward_min': -20.0, 'episode_reward_mean': -11.6, 'episode_len_mean': 3668.28, 'episode_media': {}, 'episodes_this_iter': 1, 'episodes_timesteps_total': 366828, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-16.0, -18.0, -19.0, -12.0, -7.0, -16.0, -14.0, -15.0, -8.0, -18.0, -12.0, -12.0, -13.0, -15.0, -12.0, -9.0, -9.0, -10.0, -11.0, -16.0, -18.0, -16.0, -12.0, -14.0, -17.0, -18.0, -15.0, -13.0, -10.0, -14.0, -12.0, -13.0, -14.0, -6.0, -11.0, -13.0, -7.0, -12.0, 8.0, -7.0, -7.0, -16.0, -10.0, -14.0, -3.0, -14.0, -15.0, -10.0, -6.0, -13.0, -7.0, -12.0, -13.0, -16.0, -13.0, -6.0, -13.0, -17.0, -15.0, -10.0, -11.0, -11.0, -7.0, -12.0, -6.0, -15.0, -16.0, -9.0, -4.0, -11.0, -11.0, -5.0, -11.0, -7.0, -9.0, -15.0, -16.0, -9.0, -19.0, -8.0, -13.0, -5.0, -13.0, -5.0, -15.0, -14.0, -5.0, -16.0, -11.0, -7.0, -20.0, -18.0, -14.0, -13.0, -9.0, -11.0, -11.0, -11.0, -6.0, -5.0], 'episode_lengths': [2441, 2567,
 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0, 'connector_metrics': {'ObsPreprocessorConnector_ms': 0.027622699737548828, 'StateBufferConnector_ms': 0.005634784698486328, 'ViewRequirementAgentConnector_ms': 0.12884807586669922}, 'num_episodes': 0, 'episode_return_max': -1.0, 'episode_return_min': -21.0, 'episode_return_mean': -12.16}, 'env_runner_results': {'episode_reward_max': -1.0, 'episode_reward_min': -21.0, 'episode_reward_mean': -12.16, 'episode_len_mean': 3669.67, 'episode_media': {}, 'episodes_this_iter': 0, 'episodes_timesteps_total': 366967, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-14.0, -15.0, -13.0, -12.0, -16.0, -17.0, -16.0, -16.0, -17.0, -17.0, -14.0, -15.0, -17.0, -13.0, -18.0, -2.0, -15.0, -11.0, -8.0, -11.0, -12.0, -9.0, -13.0, -9.0, -8.0, -7.0, -5.0, -12.0, -13.0, -12.0, -7.0, -20.0, -9.0, -15.0, -18.0, -16.0, -14.0, -10.0, -9.0, -12.0, -5.0, -14.0, -15.0, -14.0, -15.0, -18.0, -18.0, -12.0, -13.0, -13.0, -17.0, -11.0, -11.0, -9.0, -8.0, -7.0, -14.0, -8.0, -15.0, -21.0, -18.0, -1.0, -16.0, -8.0, -10.0, -6.0, -15.0, -7.0, -9.0, -4.0, -10.0, -9.0, -10.0, -16.0, -12.0, -14.0, -12.0, -3.0, -16.0, -14.0, -4.0, -15.0, -12.0, -18.0, -15.0, -14.0, -9.0, -11.0, -15.0, -11.0, -14.0, -12.0, -11.0, -12.0, -10.0, -10.0, -8.0, -11.0, -14.0, -15.0], 'episode_lengths': [2623, 2830, 3151, 3415, 2339, 2129, 2629, 2413, 2155, 2559, 2792, 2264, 3128, 2714, 2742, 5559, 3642, 3758, 5169, 3407, 3951, 3575, 3572, 4765, 4426, 3716, 5075, 3484, 3742, 5345, 4348, 2646, 3736, 2960, 2770, 2694, 3185, 4051, 4442, 3659, 4984, 3413, 3535, 3456, 3124, 3514, 2704, 3348, 3184, 3200, 2433, 2928, 3042, 3640, 4201, 5434, 4029, 4409, 4544, 1882, 2409, 5803, 2963, 4886, 4126, 4739, 4350, 5218, 4838, 4978, 3729, 4455, 4768, 3209, 3278, 3839, 4383, 5605,  ...
#         0.02554275, -0.2092535 , -0.28322813,  0.05236921, -0.39008868,
#         0.04305805,  0.0789693 , -0.01872359, -0.00285816,  0.24171375,
#        -0.0021393 ,  0.08773953, -0.13998178,  0.07125621, -0.03797716,
#         0.05902719,  0.00866015, -0.07924633, -0.00149259,  0.29391068,
#        -0.04147601, -0.6876892 , -0.05919394,  0.09753431,  0.48050478,
#         0.1410949 ,  0.04819775], dtype=float32), 'mean_td_error': 0.004030025098472834}}, 'num_env_steps_sampled': 2000000, 'num_env_steps_trained': 6396800, 'num_agent_steps_sampled': 2000000, 'num_agent_steps_trained': 6396800, 'last_target_update_ts': 1995000, 'num_target_updates': 266}, 'sampler_results': {'episode_reward_max': -2.0, 'episode_reward_min': -19.0, 'episode_reward_mean': -13.22, 'episode_len_mean': 3778.73, 'episode_media': {}, 'episodes_this_iter': 0, 'episodes_timesteps_total': 377873, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [
885, 3808, 4614, 3998, 3553, 5463, 4544, 4831, 3820, 6436, 4338, 3693, 4496, 5248, 6208, 4088, 5148, 5454, 3318, 5488, 5595, 6814, 6662, 5998, 2054, 6419, 6463, 5092, 3572, 7771, 9118, 7675, 3198, 5315, 7289, 5549, 10406, 8546, 9954, 4985, 5323, 4786, 6589, 6761, 5490, 4400, 4444, 5802, 6165, 6650, 4904, 4563, 4796, 3836, 4587, 5215, 4610, 4335, 4241]}, 'sampler_perf': {'mean_raw_obs_processing_ms': 0.4799273902955228, 'mean_inference_ms': 3.2456323099402216, 'mean_action_processing_ms': 0.15973210181092645, 'mean_env_wait_ms': 0.3942197965757835, 'mean_env_render_ms': 0.0}, 'num_faulty_episodes': 0, 'connector_metrics': {'ObsPreprocessorConnector_ms': 0.03372955322265625, 'StateBufferConnector_ms': 0.006497859954833984, 'ViewRequirementAgentConnector_ms': 0.12117767333984375}, 'num_episodes': 0, 'episode_return_max': 3.0, 'episode_return_min': -19.0, 'episode_return_mean': -11.35}, 'env_runner_results': {'episode_reward_max': 3.0, 'episode_reward_min': -19.0, 'episode_reward_mean': -11.35, 'episode_len_mean': 5334.26, 'episode_media': {}, 'episodes_this_iter': 0, 'episodes_timesteps_total': 533426, 'policy_reward_min': {}, 'policy_reward_max': {}, 'policy_reward_mean': {}, 'custom_metrics': {}, 'hist_stats': {'episode_reward': [-12.0, -12.0, -12.0, -11.0, -13.0, -14.0, -15.0, -11.0, -12.0, -14.0, -13.0, -13.0, -7.0, -10.0, -9.0, -4.0, -7.0, -6.0, -12.0, -13.0, -4.0, -16.0, -5.0, -9.0, -13.0, -15.0, -11.0, -11.0, -16.0, -12.0, -11.0, -19.0, -13.0, -13.0, -14.0, -15.0, -13.0, -13.0, -11.0, -16.0, -13.0, -8.0, -15.0, -9.0, -14.0, -16.0, -10.0, -16.0, -16.0, -16.0, -3.0, -18.0, -17.0, -13.0, -15.0, -6.0, -14.0, -13.0, -10.0, -16.0, -9.0, -12.0, -6.0, -4.0, 3.0, -16.0, -5.0, -2.0, -13.0, -17.0, -7.0, -8.0, -12.0, -14.0, -14.0, -8.0, -12.0, -3.0, -4.0, -5.0, -10.0, -8.0, -15.0, -9.0, -4.0, -11.0, -17.0, -13.0, -11.0, -12.0, -7.0, -11.0, -15.0, -15.0, -15.0, -14.0, -11.0, -10.0, -15.0, -16.0], 'episode_lengths': [5844, 4877, 4612, 5177, 4881, 5130, 3997, 5639, 5000, 3726, 3958, 4756, 7479, 4995, 5743, 8271, 6262, 6622, 4601, 5232, 6938, 2924, 6165, 5078, 4492, 4370, 5685, 5239, 5367, 4410, 4706, 3556, 4976, 7423, 6493, 5856, 4261, 5535, 5751, 4717, 4279, 3885, 3808, 4614, 3998, 3553, 5463, 4544, 4831, 3820, 6436, 4338, 3693, 4496, 5248, 6208, 4088, 5148, 5454, 3318, 5488, 5595, 6814, 6662, 5998, 2054, 6419, 6463, 5092, 3572, 7771, 9118, 7675, 3198, 5315, 7289, 5549, 10406, 8546, 995 ...

# %%
config = dqn.DQNConfig()



config["env"] = "Pong-ram-v4"
config["framework"] = "torch"

#Environment configs
config['model']['grayscale'] = True
config['model']['dim'] = 84
config['model']['zero_mean'] = True
config['sample_batch_size'] = 4
# config['rollout_fragment_length'] = 4

# Rainbow DQN Parameters
config["dueling"] = False
config["double_q"] = False
config["noisy"] = False

# Rainbow DQN numerical Parameters
config['num_atoms'] = 1
config["n_step"] = 10
config['v_min'] = -12.0
config['v_max'] = 12.0
config['sigma0'] = 0.2

# DQN layers
config["model"] = {"fcnet_hiddens": [512], "fcnet_activation": "relu"}

# Action selection configs
config['exploration_config'] = {'type': 'EpsilonGreedy', 'initial_epsilon':1.0, 'final_epsilon':.001, 'epsilon_timesteps': 40000}

# Replay buffer configurations
# https://docs.ray.io/en/latest/_modules/ray/rllib/utils/replay_buffers/prioritized_replay_buffer.html 
config["replay_buffer_config"] = {
                "type": "MultiAgentPrioritizedReplayBuffer",
                "capacity": 75000,
                "prioritized_replay_alpha": 0.7,
                "prioritized_replay_beta": 0.3,
                "prioritized_replay_eps": 0.00001,
                # "replay_sequence_length" : 1
            }

# Training configs
config["train_batch_size"] = 32
config["timesteps_per_iteration"] = 10000   
config["target_network_update_freq"] = 7500
config['gamma'] = 0.99
config['lr'] = 0.001
# config['adam_epsilon'] = 0.0020
config["num_gpus"] = 1
config['num_workers'] = 8
# config['compress_observations'] = True  

analysis3 = tune.run("DQN", name = "Model", metric = "episode_reward_min", num_samples = 1, checkpoint_freq = 10, config = config)
# Out:
# 2024-05-12 08:12:20,403	INFO tune.py:614 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# 2024-05-12 08:12:20,408	WARNING callback.py:136 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-05-12 13:24:19</td></tr>
# <tr><td>Running for: </td><td>05:11:58.91        </td></tr>
# <tr><td>Memory:      </td><td>8.0/13.9 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc            </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">     ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Pong-ram-v4_f9035_00000</td><td>RUNNING </td><td>127.0.0.1:19560</td><td style="text-align: right;">  3184</td><td style="text-align: right;">         18610.2</td><td style="text-align: right;">3184000</td><td style="text-align: right;">  -10.75</td><td style="text-align: right;">                   4</td><td style="text-align: right;">                 -18</td><td style="text-align: right;">           5455.96</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name                 </th><th style="text-align: right;">  agent_timesteps_total</th><th>connector_metrics                                                                                                                                             </th><th>counters                                                                                                                                                                                                   </th><th>custom_metrics  </th><th>env_runner_results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             </th><th style="text-align: right;">  episode_len_mean</th><th>episode_media  </th><th style="text-align: right;">  episode_return_max</th><th style="text-align: right;">  episode_return_mean</th><th style="text-align: right;">  episode_return_min</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_mean</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episodes_this_iter</th><th style="text-align: right;">  episodes_timesteps_total</th><th>info  </th><th style="text-align: right;">  num_agent_steps_sampled</th><th style="text-align: right;">  num_agent_steps_sampled_lifetime</th><th style="text-align: right;">  num_agent_steps_trained</th><th style="text-align: right;">  num_env_steps_sampled</th><th style="text-align: right;">  num_env_steps_sampled_lifetime</th><th style="text-align: right;">  num_env_steps_sampled_this_iter</th><th style="text-align: right;">  num_env_steps_sampled_throughput_per_sec</th><th style="text-align: right;">  num_env_steps_trained</th><th style="text-align: right;">  num_env_steps_trained_this_iter</th><th style="text-align: right;">  num_env_steps_trained_throughput_per_sec</th><th style="text-align: right;">  num_episodes</th><th style="text-align: right;">  num_faulty_episodes</th>< ...
# </thead>
# <tbody>
# <tr><td>DQN_Pong-ram-v4_f9035_00000</td><td style="text-align: right;">                3184000</td><td>{&#x27;ObsPreprocessorConnector_ms&#x27;: 0.03008580207824707, &#x27;StateBufferConnector_ms&#x27;: 0.003200054168701172, &#x27;ViewRequirementAgentConnector_ms&#x27;: 0.11515998840332031}</td><td>{&#x27;num_env_steps_sampled&#x27;: 3184000, &#x27;num_env_steps_trained&#x27;: 10185600, &#x27;num_agent_steps_sampled&#x27;: 3184000, &#x27;num_agent_steps_trained&#x27;: 10185600, &#x27;last_target_update_ts&#x27;: 3180000, &#x27;num_target_updates&#x27;: 424}</td><td>{}              </td><td>{&#x27;episode_reward_max&#x27;: 4.0, &#x27;episode_reward_min&#x27;: -18.0, &#x27;episode_reward_mean&#x27;: -10.75, &#x27;episode_len_mean&#x27;: 5455.96, &#x27;episode_media&#x27;: {}, &#x27;episodes_this_iter&#x27;: 0, &#x27;episodes_timesteps_tot

# %%
config = dqn.DQNConfig()



config["env"] = "Pong-ram-v4"
config["framework"] = "torch"

#Environment configs
config['model']['grayscale'] = True
config['model']['dim'] = 84
config['model']['zero_mean'] = True
config['sample_batch_size'] = 4
# config['rollout_fragment_length'] = 4

# Rainbow DQN Parameters
config["dueling"] = False
config["double_q"] = False
config["noisy"] = False

# Rainbow DQN numerical Parameters
config['num_atoms'] = 1
config["n_step"] = 10
config['v_min'] = -12.0
config['v_max'] = 12.0
config['sigma0'] = 0.2

# DQN layers
config["model"] = {"fcnet_hiddens": [512], "fcnet_activation": "relu"}

# Action selection configs
config['exploration_config'] = {'type': 'EpsilonGreedy', 'initial_epsilon':1.0, 'final_epsilon':.001, 'epsilon_timesteps': 4000}

# Replay buffer configurations
# https://docs.ray.io/en/latest/_modules/ray/rllib/utils/replay_buffers/prioritized_replay_buffer.html 
config["replay_buffer_config"] = {
                "type": "MultiAgentPrioritizedReplayBuffer",
                "capacity": 75000,
                "prioritized_replay_alpha": 0.7,
                "prioritized_replay_beta": 0.3,
                "prioritized_replay_eps": 0.0001,
                # "replay_sequence_length" : 1
            }

# Training configs
config["train_batch_size"] = 32
config["timesteps_per_iteration"] = 1000   
config["target_network_update_freq"] = 1000
config['gamma'] = 0.99
config['lr'] = 0.0001
# config['adam_epsilon'] = 0.0020
config["num_gpus"] = 1
config['num_workers'] = 8
# config['compress_observations'] = True  

analysis4 = tune.run("DQN", name = "Model", metric = "episode_reward_min", num_samples = 1, stop={"timesteps_total":200000}, checkpoint_freq = 10, config = config)
# Out:
# 2024-05-12 14:06:56,366	INFO tune.py:614 -- [output] This uses the legacy output and progress reporter, as Jupyter notebooks are not supported by the new engine, yet. For more information, please see https://github.com/ray-project/ray/issues/36949
# 2024-05-12 14:06:56,371	WARNING callback.py:136 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2024-05-12 14:10:12</td></tr>
# <tr><td>Running for: </td><td>00:03:15.40        </td></tr>
# <tr><td>Memory:      </td><td>10.3/13.9 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/12 CPUs, 1.0/1 GPUs (0.0/1.0 accelerator_type:G)
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name                 </th><th>status  </th><th>loc           </th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">     ts</th><th style="text-align: right;">  reward</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episode_len_mean</th></tr>
# </thead>
# <tbody>
# <tr><td>DQN_Pong-ram-v4_f9035_00000</td><td>RUNNING </td><td>127.0.0.1:1524</td><td style="text-align: right;">  3569</td><td style="text-align: right;">         20922.4</td><td style="text-align: right;">3569000</td><td style="text-align: right;">   -13.6</td><td style="text-align: right;">                  -6</td><td style="text-align: right;">                 -19</td><td style="text-align: right;">            5237.4</td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# 2024-05-12 14:06:56,390	INFO tune_controller.py:444 -- Restoring the run from the latest experiment state file: experiment_state-2024-05-12_13-51-01.json
# <div class="trialProgress">
#   <h3>Trial Progress</h3>
#   <table>
# <thead>
# <tr><th>Trial name                 </th><th style="text-align: right;">  agent_timesteps_total</th><th>connector_metrics                                                                                                                                           </th><th>counters                                                                                                                                                                                                   </th><th>custom_metrics  </th><th>env_runner_results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     </th><th style="text-align: right;">  episode_len_mean</th><th>episode_media  </th><th style="text-align: right;">  episode_return_max</th><th style="text-align: right;">  episode_return_mean</th><th style="text-align: right;">  episode_return_min</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_mean</th><th style="text-align: right;">  episode_reward_min</th><th style="text-align: right;">  episodes_this_iter</th><th style="text-align: right;">  episodes_timesteps_total</th><th>info  </th><th style="text-align: right;">  num_agent_steps_sampled</th><th style="text-align: right;">  num_agent_steps_sampled_lifetime</th><th style="text-align: right;">  num_agent_steps_trained</th><th style="text-align: right;">  num_env_steps_sampled</th><th style="text-align: right;">  num_env_steps_sampled_lifetime</th><th style="text-align: right;">  num_env_steps_sampled_this_iter</th><th style="text-align: right;">  num_env_steps_sampled_throughput_per_sec</th><th style="text-align: right;">  num_env_steps_trained</th><th style="text-align: right;">  num_env_steps_trained_this_iter</th><th style="text-align: right;">  num_env_steps_trained_throughput_per_sec</th><th style="text-align: right;">  num_episodes</th><th style="text-align: right;">  num_faulty_episodes</th><th style="text-align: right;">  num_healthy_workers</th><th style="text-align: right;">  num_in_flight_async_reqs</th><th style="text-align: right;">  num_remote_worker_restarts</th><th style="text-align: right;">  num_steps_trained_this_iter</th><th>perf                                                             </th><th>policy_reward_max  </th><th>policy_reward_mean  </th><th>policy_reward_min  </th><th>sampler_perf                                                                                                                                                                                                   </th><th>sampler_results                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          ...
# </thead>
# <tbody>
# <tr><td>DQN_Pong-ram-v4_f9035_00000</td><td style="text-align: right;">                3569000</td><td>{&#x27;ObsPreprocessorConnector_ms&#x27;: 0.06580829620361328, &#x27;StateBufferConnector_ms&#x27;: 0.02002716064453125, &#x27;ViewRequirementAgentConnector_ms&#x27;: 0.0801992416381836}</td><td>{&#x27;num_env_steps_sampled&#x27;: 3569000, &#x27;num_env_steps_trained&#x27;: 11417600, &#x27;num_agent_steps_sampled&#x27;: 3569000, &#x27;num_agent_steps_trained&#x27;: 11417600, &#x27;last_target_update_ts&#x27;: 3562500, &#x27;num_target_updates&#x27;: 475}</td><td>{}              </td><td>{&#x27;episode_reward_max&#x27;: -6.0, &#x27;episode_reward_min&#x27;: -19.0, &#x27;episode_reward_mean&#x27;: -13.6, &#x27;episode_len_mean&#x27;: 5237.4, &#x27;episode_media&#x27;: {}, &#x27;episodes_this_iter&#x27;: 0, &#x27;episodes_timesteps_total&#x27;: 26187, &#x27;policy_reward_min&#x27;: {}, &#x27;policy_reward_max&#x27;: {}, &#x27;policy_reward_mean&#x27;: {}, &#x27;custom_metrics&#x27;: {}, &#x27;hist_stats&#x27;: {&#x27;episode_reward&#x27;: [-13.0, -13.0, -19.0, -17.0, -6.0], &#x27;episode_lengths&#x27;: [6402, 5952, 3690, 2492, 7651]}, &#x27;sampler_perf&#x27;: {&#x27;mean_raw_obs_processing_ms&#x27;: 0.3861785902662698, &#x27;mean_inference_ms&#x27;: 2.596533392474678, &#x27;mean_action_processing_ms&#x27;: 0.1301633915421912, &#x27;mean_env_wait_ms&#x27;: 0.33504581225333097, &#x27;mean_env_render_ms&#x27;: 0.0}, &#x27;num_faulty_episodes&#x27;: 0, &#x27;connector_metrics&#x27;: {&#x27;ObsPreprocessorConnector_ms&#x27;: 0.06580829620361328, &#x27;StateBufferConnector_ms&#x27;: 0.02002716064453125, &#x27;ViewRequirementAgentConnector_ms&#x27;: 0.0801992416381836}, &#x27;num_episodes&#x27;: 0, &#x27;episode_return_max&#x27;: -6.0, &#x27;episode_return_min&#x27;: -19.0, &#x27;episode_return_mean&#x27;: -13.6}</td><td style="text-align: right;">            5237.4</td><td>{}             </td><td style="text-align: right;">                  -6</td><td style="text-align: right;">                -13.6</td><td style="text-align: right;">                 -19</td><td style="text-align: right;">                  -6</td><td style="text-align: right;">                -13.6</td><td style="text-align: right;">                 -19</td><td style="text-align: right;">                   0</td><td style="text-align: right;">                     26187</td><td>{&#x27;learner&#x27;: {&#x27;default_policy&#x27;: {&#x27;custom_metrics&#x27;: {}, &#x27;learner_stats&#x27;: {&#x27;mean_q&#x27;: 0.059340186417102814, &#x27;min_q&#x27;: -0.27905943989753723, &#x27;max_q&#x27;: 0.6501115560531616, &#x27;cur_lr&#x27;: 0.001}, &#x27;model&#x27;: {}, &#x27;num_grad_updates_lifetime&#x27;: 2900.0, &#x27;diff_num_grad_updates_vs_sampler_policy&#x27;: 1076.28125, &#x27;td_error&#x27;: array([-0.30562556, -0.01657704,  0.04535597,  0.01320946, -0.32428652,
#         0.0773478 ,  0.11921991, -0.08901522, -0.24969688,  0.6331247 ,
#        -0.55752826,  0.4573088 , -0.0315091 ,  0.57623935,  0.00927612,
#         0.05947449,  0.05441362, -0.44052798, -0.11828522, -0.26728195,
#         0.06252676, -0.07054532, -0.03874089, -0.15771793,  0.10841278,
#        -0.7208102 , -0.02221045,  0.01932745, -0.03670928, -0.16369665,
#        -0.01231128, -0.0075
# 2024-05-12 14:10:12,159	WARNING tune.py:219 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.
# 2024-05-12 14:10:12,193	WARNING experiment_state.py:205 -- Experiment state snapshotting has been triggered multiple times in the last 5.0 seconds. A snapshot is forced if `CheckpointConfig(num_to_keep)` is set, and a trial has checkpointed >= `num_to_keep` times since the last snapshot.
# You may want to consider increasing the `CheckpointConfig(num_to_keep)` or decreasing the frequency of saving checkpoints.
# You can suppress this error by setting the environment variable TUNE_WARN_EXCESSIVE_EXPERIMENT_CHECKPOINT_SYNC_THRESHOLD_S to a smaller value than the current threshold (5.0).
# 2024-05-12 14:10:12,275	INFO tune.py:1007 -- Wrote the latest version of all result files and experiment state to 'C:/Users/Sean/ray_results/Model' in 0.1162s.
# 2024-05-12 14:10:14,823	INFO tune.py:1039 -- Total run time: 198.46 seconds (195.28 seconds for the tuning loop).
# 2024-05-12 14:10:14,824	WARNING tune.py:1054 -- Experiment has been interrupted, but the most recent state was saved.
# Resume experiment with: tune.run(..., resume=True)
